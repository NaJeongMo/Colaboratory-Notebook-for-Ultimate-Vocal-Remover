# %% [markdown]
# #<font color="Green">Vocal Remover 5.0.1</font>
# <br>Trained models provided in this notebook are by [Anjok07](https://github.com/Anjok07), and [aufr33](https://github.com/aufr33).</br>
# <br>OFFICIAL UVR GITHUB PAGE: [here](https://github.com/Anjok07/ultimatevocalremovergui).</br>
# <br>OFFICIAL CLI Version: [here](https://github.com/tsurumeso/vocal-remover).</br>
# <sup><br>Powered by [tsurumeso](http://github.com/tsurumeso/).
# <br>Colaboratory version by [AudioHacker](https://www.youtube.com/channel/UC0NiSV1jLMH-9E09wiDVFYw).</br></sup>

# %%
# ------------VSC REWRITE
# pyright: reportMissingImports=false, reportUnusedVariable=warning, reportUntypedBaseClass=error
#@title Mount to Drive

modloc = False
#--------snippets-----------
#/content/drive/Shareddrives/PREY
#/content/drive/Shareddrives/Shared Drive

mounting_path = '/content/drive/MyDrive' # DEFAULT
if modloc:
    mounting_path = input('Enter custom path: ')
    print(f'UVR WILL BE INSTALLED IN {mounting_path}')
    
#update channels
# ai = '1bkOTtPI6nnVmxG8UgUjYMwgqrmGAsBUc' # // DRIVE
ai = 'https://github.com/NaJeongMo/Colaboratory-Notebook-for-Ultimate-Vocal-Remover'
model_p1 = 'https://github.com/NaJeongMo/Colaboratory-Notebook-for-Ultimate-Vocal-Remover/releases/download/5.0.1%2Fc1.0/models_v5.zip'
model_p2 = 'https://github.com/NaJeongMo/Colaboratory-Notebook-for-Ultimate-Vocal-Remover/releases/download/5.0.1%2Fc1.0/models_v5_new.zip'
model_v5np2 = 'https://github.com/NaJeongMo/Colaboratory-Notebook-for-Ultimate-Vocal-Remover/releases/download/5.0.2%2Fc1.01/models_v5_new_p2.zip'
vercheck = 'https://VocalRemover501.tzuyuhv.repl.co/v501_/check_ver'
#vercheck = '1oNPL-DexhzhheG_o9Zsmu4oegV-QALoP' # // DRIVE
from IPython.display import Audio, display
from google.colab import output
from google.colab import drive
from google.colab import files
from sys import exit
import zipfile
import hashlib
import os.path
import shutil
import psutil
import random
import glob
import sys
import os
#@markdown Uncheck if you want to use VocalRemover5 without mounting to drive.
MountDrive = True #@param{type:"boolean"}
## output.clear()
class hide_opt: # hide outputs
    def __enter__(self):
        self._original_stdout = sys.stdout
        sys.stdout = open(os.devnull, 'w')
    def __exit__(self, exc_type, exc_val, exc_tb):
        sys.stdout.close()
        sys.stdout = self._original_stdout

def get_size(bytes, suffix='B'): # read ram
    global svmem
    factor = 1024
    for unit in ["", "K", "M", "G", "T", "P"]:
        if bytes < factor:
            return f'{bytes:.2f}{unit}{suffix}'
        bytes /= factor
    svmem = psutil.virtual_memory()

def installAI():
    with hide_opt():

        get_ipython().system('git clone {} VocalRemover5-COLAB_arch'.format(ai))
        os.chdir('VocalRemover5-COLAB_arch')

        get_ipython().system('wget {}'.format(model_p1))
        get_ipython().system('unzip -o models_v5.zip')
        os.remove('models_v5.zip')

        get_ipython().system('wget {}'.format(model_v5np2))
        get_ipython().system('unzip -o models_v5_new_p2.zip')
        os.remove('models_v5_new_p2.zip')

        get_ipython().system('wget {}'.format(model_p2))
        get_ipython().system('unzip -o models_v5_new.zip')
        os.remove('models_v5_new.zip')

def mount_to_colab(): # cd to drive
    os.chdir(f'{mounting_path}/VocalRemover5-COLAB_arch')
    print('Success!')

def vrmount(): # install ai and or cd to drive
    drive.mount("/content/drive", force_remount=True)
    os.chdir(mounting_path + '/')
    if os.path.isdir(f'{mounting_path}/VocalRemover5-COLAB_arch'):
        check_update()
        mount_to_colab()
    else:
        print("Uh oh! It looks like it's your first time using VocalRemover5!")
        print('About 4 gb of Google Drive will be used.')
        confirmation = input('Do you want to continue? (y/n): ')
        if confirmation.lower() == 'y':
            print('')
            print ("Downloading VR5...")
            installAI()
            mount_to_colab()
        else:
            print('Please uncheck MountDrive')
            exit()

def dlvr(): # download vr to colab only
    print('Warning: changes will not be saved.')
    print('Downloading VR5...')
    with hide_opt():
        os.chdir('/content')
    installAI()
    #os.chdir('/content/VocalRemover5-COLAB_arch')
    print ("Success!")

def check_update():
    if os.path.isdir(f'{mounting_path}/VocalRemover5-COLAB_arch'): # check update if ai installed is True
        os.chdir(f'{mounting_path}/VocalRemover5-COLAB_arch')
        print("Checking for updates...", end=" ")
        with hide_opt():
            get_ipython().system('wget {} -O check_ver'.format(vercheck))
        f = open("check_ver", "r")
        nver = f.read()
        f = open("v", "r")
        cver = f.read()
        if cver != nver:
            print('New update found! {}'.format(nver))
            os.chdir('../')
            with hide_opt():
                get_ipython().system('git clone {} temp_VocalRemover5-COLAB_arch'.format(ai))
            get_ipython().system('cp -a temp_VocalRemover5-COLAB_arch/* VocalRemover5-COLAB_arch/')
            get_ipython().system('rm -rf temp_VocalRemover5-COLAB_arch')
            with hide_opt():
                os.chdir('VocalRemover5-COLAB_arch')
                get_ipython().system('wget {}'.format(model_p1))
                get_ipython().system('unzip -o models_v5.zip')
                os.remove('models_v5.zip')

                get_ipython().system('wget {}'.format(model_v5np2))
                get_ipython().system('unzip -o models_v5_new_p2.zip')
                os.remove('models_v5_new_p2.zip')

                get_ipython().system('wget {}'.format(model_p2))
                get_ipython().system('unzip -o models_v5_new.zip')
                os.remove('models_v5_new.zip')
            output.clear()
            os.remove(f'{mounting_path}/VocalRemover5-COLAB_arch/v')
            os.rename(f'{mounting_path}/VocalRemover5-COLAB_arch/check_ver',f'{mounting_path}/VocalRemover5-COLAB_arch/v')
            os.chdir(f'{mounting_path}/VocalRemover5-COLAB_arch')
            #os.remove('v')
            #with hide_opt():
            #    get_ipython().system('wget {} -O v'.format(vercheck))
        else:
            os.remove('check_ver')
            print('No update found.')
    else:
        if MountDrive:
            vrmount() # colab
        elif MountDrive == False:
            if os.path.isdir('/content/VocalRemover5-COLAB_arch'):
                print("Success!")
            else:
                dlvr()
# Import other modules for cell-inference
with hide_opt():
    ! pip install pathvalidate
    ! pip install youtube-dl
    ! pip install samplerate

    ! pip install librosa==0.8.0
    ! pip install numba==0.48.0
    ! pip install resampy==0.2.2

    from pathvalidate import sanitize_filename # for inference
    import youtube_dl # for inference
#-------------Script begin-------------

if MountDrive:
    vrmount()
else:
    if os.path.isdir('/content/VocalRemover5-COLAB_arch') == False:
        if os.path.isdir('/content/VocalRemover5-COLAB_arch'):
            print('Success!')
        else:
            dlvr()


gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)

if gpu_info.find('failed') >= 0:
    svmem = psutil.virtual_memory()
    print(f'GPU runtime is disabled. You have {get_size(svmem.total)} RAM.')
if gpu_info.find('Tesla T4') >= 0:
    print('You got a Tesla T4 GPU. (Speeds are around 10-25 it/s)')
elif gpu_info.find('Tesla K80') >= 0:
    print('You got a Tesla K80 GPU. (Speeds are around 2-10 it/s)')
elif gpu_info.find('Tesla P100') >= 0:
    print('You got a Tesla P100 GPU. (Speeds are around 15-42 it/s) Lucky!')

# %% [markdown]
# #<font color="Blue">Print a list of tracks and models</font>

# %%
if os.path.isfile('main.py') == False:
  if MountDrive:
    os.chdir(mounting_path + '/VocalRemover5-COLAB_arch')
  else:
    os.chdir('/content/VocalRemover5-COLAB_arch')
#@title <- Press me
print("Here's a list of files in your tracks folder:")
print("")
! ls tracks/
print("")
print("---------------------------------------------------")
print("")
print("Usable models:")
print("")
print("   v5 (new arch):")
! ls models/v5_new
print("   v5:")
! ls models/v5
print("---------------------------------------------------")
print("")
print("Usable parameters:")
print("")
! ls modelparams/
print("---------------------------------------------------")
print("")
print("Your separated files:")
print("")
! ls separated/

# %% [markdown]
# #Inference

# %%
# ------------VSC REWRITE
#type: ignore
if os.path.isfile('main.py') == False:
    if MountDrive:
        os.chdir(mounting_path + '/VocalRemover5-COLAB_arch')
    else:
        os.chdir('/content/VocalRemover5-COLAB_arch')

def zipdir(path, ziph):
    # ziph is zipfile handle
    for root, dirs, files in os.walk(path):
        for file in files:
            ziph.write(os.path.join(root, file), 
                       os.path.relpath(os.path.join(root, file), 
                                       os.path.join(path, '..')))
debug = False
def YouTube(link, dl=True):
    inputsha = hashlib.sha1(bytes(link, encoding='utf8')).hexdigest() + '.wav'
    fmt = '251/140/250/139'
    opt = {'format': fmt, 'outtmpl': inputsha, 'updatetime': False, 'nocheckcertificate': True}
    if dl == True:
        print('YouTube link detected')
        print('Downloading...', end=' ')
    with hide_opt():
        with youtube_dl.YoutubeDL(opt) as ydl:
            global desc
            if dl == True:
                desc = ydl.extract_info(link, download=not os.path.isfile(inputsha))
            else:
                desc = ydl.extract_info(link, download=not True)
    if dl == True:
        print('done')
    titlename = sanitize_filename(desc['title'])
    if dl == True:
        print(titlename)
    if dl==False:
        return titlename
    else:
        return titlename, inputsha

#parameter markdowns-----------------

#@markdown ### Input files
#@markdown Track name / any link (Upload your songs in tracks folder)
input = "Enter any link or filename" #@param {type:"string"}
#@markdown Convert all files in your tracks folder
convertAll = False #@param {type:"boolean"}
if convertAll:
    convertAll = '--convert_all'
else:
    convertAll = ''
#@markdown Model name (Upload your models in models folder)
pretrained_model = "HP2-4BAND-3090_4band_arch-500m_1.pth" #@param ["HP_4BAND_3090_arch-124m.pth","HP2-4BAND-3090_4band_arch-500m_1.pth","HP2-4BAND-3090_4band_arch-500m_2.pth","Vocal_HP_4BAND_3090_AGG_arch-124m.pth","Vocal_HP_4BAND_3090_arch-124m.pth","HP_4BAND_arch-124m_3090.pth","HighPrecison_4band_arch-124m_1.pth","HighPrecison_4band_arch-124m_2.pth","LOFI_2band-1_arch-34m.pth","LOFI_2band-2_arch-34m.pth","NewLayer_4band_arch-130m_1.pth","NewLayer_4band_arch-130m_2.pth","NewLayer_4band_arch-130m_3.pth","MGM-v5-2Band-32000-_arch-default-BETA1.pth","MGM-v5-2Band-32000-_arch-default-BETA2.pth","MGM-v5-3Band-44100-_arch-default-BETA.pth","MGM-v5-4Band-44100-_arch-default-BETA1.pth","MGM-v5-4Band-44100-_arch-default-BETA2.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA1.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA2-AGR.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA1.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA2.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA1.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA2.pth"]{allow-input: true}
#@markdown ---
#@markdown ### Arguments
window_size =  320#@param {type:"integer"}
if window_size < 320:
    print('Warning: window_size lower than 320.')
if window_size < 272:
    window_size = 272
autoDetect_param = True #@param {type:"boolean"}
#1band_sr32000_hl512.json  2band_44100_lofi.json  3band_44100_mid.json
#1band_sr44100_hl512.json  2band_48000.json	 4band_44100.json
#2band_32000.json	  3band_44100.json	 ensemble.json
parameter = "4band_44100.json" #@param ["1band_sr32000_hl512.json","1band_sr44100_hl512.json", "2band_32000.json" , "2band_44100_lofi.json", "2band_48000.json", "3band_44100.json", "3band_44100_mid.json", "4band_44100.json"]
parameter = "modelparams/" + parameter
high_end_process = 'none' #@param ["none","mirroring", "mirroring2" , "bypass"]
aggressiveness = '0.275' #@param {type:"string"}
aggressiveness = float(aggressiveness)
#@markdown ### Architecture
nn_architecture = 'Auto detect' #@param ["Auto detect","default", "34 MB", "124 MB", "130 MB", "500 MB"]
if nn_architecture == '34 MB':
    nn_architecture = '33966KB'
elif nn_architecture == '124 MB':
    nn_architecture = '123821KB'
elif nn_architecture == '130 MB':
    nn_architecture = '129605KB'
elif nn_architecture == '500 MB':
    nn_architecture = '537238KB'
elif nn_architecture == 'default':
    pass
#@markdown ---
#@markdown ### Checkboxes
#@markdown Use GPU for faster conversion
gpu = True #@param {type: "boolean"}
if gpu == True:
    gpu = 0
else:
    gpu = -1
#@markdown Aggressively remove vocals from Instrumental
deepExtraction = False #@param {type:"boolean"}
if deepExtraction:
    deepExtraction = "-D"
else:
    deepExtraction = ""
#@markdown Flip Instruments and Vocals output (Only for Vocal Models)
isVocal = False #@param {type:"boolean"}
if isVocal:
    isVocal = '--isVocal'
else:
    isVocal = ''
#@markdown Hide warnings
suppress = True #@param {type:"boolean"}
if suppress:
    suppress = '--suppress'
else:
    suppress = ''
#@markdown Export spectogram image
output_image = False #@param {type: "boolean"}
if output_image:
    output_image = "-I"
else:
    output_image = ""
#@markdown Mute low volume vocals
postprocess = False #@param {type: "boolean"}
if postprocess:
    postprocess = "-p"
else:
    postprocess = ""
#@markdown perform Test Time Augmentation to improve the separation quality
tta = False #@param {type: "boolean"}
if tta:
    tta = "-t"
else:
    tta = ""
#@markdown Use custom arguments
useCustomArguments = False #@param {type: "boolean"}
CustomArguments = "-h" #@param {type:"string"}
#@markdown Download files
download = False #@param {type:"boolean"}
export_as_mp3 = True #@param {type:"boolean"}
#@markdown Use all model
model_version = "Don't use all model" #@param ["Don't use all model","v5_new", "v5", "all"]
# {none,v5,v5_new,all}
# automation
if nn_architecture == 'Auto detect':
    if 'arch-default' in pretrained_model:
        nn_architecture = 'default'
    elif 'arch-34m' in pretrained_model:
        nn_architecture = '33966KB'
    elif 'arch-124m' in pretrained_model:
        nn_architecture = '123821KB'
    elif 'arch-130m' in pretrained_model:
        nn_architecture = '129605KB'
    elif 'arch-500m' in pretrained_model:
        nn_architecture = '537238KB'
    else:
        print('Error! autoDetect_arch')
        print('Using 124 MB instead.')
        nn_architecture = '123821KB'
if autoDetect_param:
    if '4band' in pretrained_model:
        parameter = 'modelparams/4band_44100.json'
    elif '3Band' in pretrained_model:
        parameter = 'modelparams/3band_44100.json'
    elif 'MIDSIDE' in pretrained_model:
        parameter = 'modelparams/3band_44100_mid.json'
    elif '2Band' in pretrained_model:
        parameter = 'modelparams/2band_48000.json'
    elif 'LOFI' in pretrained_model:
        parameter = 'modelparams/2band_44100_lofi.json'
    else:
        parameter = 'modelparams/1band_sr44100_hl512.json'
if '34m' in pretrained_model or '124m' in pretrained_model or '130m' in pretrained_model or '500m' in pretrained_model:
    pretrained_model = "models/v5_new/" + pretrained_model
else:
    pretrained_model = "models/v5/" + pretrained_model
    if os.path.isfile(pretrained_model) == False:
        print('========================================================')
        print('                Error model not found.')
        print('Custom models should be uploaded in "models/v5/" folder!')
        print('========================================================')
        sys.exit()
if 'https://' not in input:
    input = 'tracks/' + input
if model_version == "Don't use all model":
    model_version = 'none'
# --------------AI----------------
isRandom = False
if useCustomArguments == False:
    if debug:
        print('Using command:')
        print(f' python3 main.py --isColab -i "{input}" {convertAll} --useAllModel "{model_version}" --model_params "{parameter}" -P "{pretrained_model}" -w {window_size} -H "{high_end_process}" --aggressiveness {aggressiveness} -n "{nn_architecture}" -g {gpu} {deepExtraction} {isVocal} {suppress} {output_image} {postprocess} {tta}')
    get_ipython().system(f'python3 main.py --isColab -i "{input}" {convertAll} --useAllModel "{model_version}" --model_params "{parameter}" -P "{pretrained_model}" -w {window_size} -H "{high_end_process}" --aggressiveness {aggressiveness} -n "{nn_architecture}" -g {gpu} {deepExtraction} {isVocal} {suppress} {output_image} {postprocess} {tta}')
    if download and convertAll:
        sys.exit("No no, this is not an error but downloading with convertAll is not yet possible. Please DON'T report this to me (Hv) or the server")
    if download:
        modelname = os.path.splitext(os.path.basename(pretrained_model))[0]
        stems = [f'_{modelname}_Instruments',f'_{modelname}_Vocals']
        if 'https://' in input:
            titlename = YouTube(input,dl=False)
            if os.path.isdir(titlename):
                shutil.rmtree(titlename)
                os.mkdir(titlename)
            if export_as_mp3:
                os.chdir('separated/')
                for i in stems:
                    if isRandom:
                        wav_path = complete_random_number + '_' + titlename + i + '.wav'
                        mp3_path = complete_random_number + '_' + titlename + i + '.mp3'
                    else:
                        wav_path = titlename + i + '.wav'
                        mp3_path = titlename + i + '.mp3'
                        get_ipython().system(f'ffmpeg -i "{wav_path}" -vn -ar 44100 -ac 2 -b:a 320k "{mp3_path}" -loglevel quiet')
                os.chdir('../')
            else:
                for move in stems:
                    shutil.move('separated/' + titlename + move + '.wav',titlename)
                zipf = zipfile.ZipFile(titlename + '.zip', 'w', zipfile.ZIP_DEFLATED)
                zipdir(titlename + '/', zipf)
                zipf.close()
                files.download(titlename + '.zip')
                shutil.rmtree(titlename)
        else:
            filename = os.path.splitext(os.path.basename(input))[0]
            if os.path.isdir(filename):
                shutil.rmtree(filename)
                os.mkdir(filename)
            if export_as_mp3:
                os.chdir('separated/')
                for i in stems:
                    wav_path = filename + i + '.wav'
                    mp3_path = filename + i + '.mp3'
                    get_ipython().system(f'ffmpeg -i "{wav_path}" -vn -ar 44100 -ac 2 -b:a 320k "{mp3_path}" -loglevel quiet')
                os.chdir('../')
                for move in stems:
                    shutil.move('separated/' + filename + move + '.mp3',filename)
            else:
                for move in stems:
                    shutil.move('separated/' + filename + move + '.wav',sanitize_filename(filename))
            zipf = zipfile.ZipFile(filename + '.zip', 'w', zipfile.ZIP_DEFLATED)
            zipdir(filename + '/', zipf)
            zipf.close()
            files.download(filename + '.zip')
            shutil.rmtree(filename)
if useCustomArguments:
    get_ipython().system(f'python3 main.py {CustomArguments}')

# %% [markdown]
# ---

# %%
#@markdown ### Custom Model Ensemble
#@markdown Arguments
input = "Enter any link or filename" #@param {type:"string"}
window_size =  320#@param {type:"integer"}
if window_size < 320:
  print('Warning: window_size lower than 320.')
if window_size < 272:
  window_size = 272
high_end_process = 'none' #@param ["none","mirroring", "mirroring2" , "bypass (Recommended for ensembling!)"]
if high_end_process == 'bypass (Recommended for ensembling!)':
    high_end_process = 'bypass'
aggressiveness = '0.275' #@param {type:"string"}
aggressiveness = float(aggressiveness)
FlipVocalModels = False #@param {type:"boolean"}
if FlipVocalModels:
    FlipVocalModels = '--flipVocals'
else:
    FlipVocalModels = ''
#@markdown Model cocktail ( ͡° ͜ʖ ͡°)

# just a quick note, you can add more model markdowns if you want.
def YouTube(link, dl=True):
    inputsha = hashlib.sha1(bytes(link, encoding='utf8')).hexdigest() + '.wav'
    fmt = '251/140/250/139'
    opt = {'format': fmt, 'outtmpl': inputsha, 'updatetime': False, 'nocheckcertificate': True}
    if dl == True:
        print('YouTube link detected')
        print('Downloading...', end=' ')
    with hide_opt():
        with youtube_dl.YoutubeDL(opt) as ydl:
            global desc
            if dl == True:
                desc = ydl.extract_info(link, download=not os.path.isfile(inputsha))
            else:
                desc = ydl.extract_info(link, download=not True)
    if dl == True:
        print('done')
    titlename = sanitize_filename(desc['title'])
    if dl == True:
        print(titlename)
    if dl==False:
        return titlename
    else:
        return titlename, inputsha

def modelPath(model):
    if model == 'slot':
        model = ''
    if '34m' in model or '124m' in model or '130m' in model or '500m' in model:
        model = "models/v5_new/" + model
    elif model == '':
        pass
    else:
        model = "models/v5/" + model
    return model

model_1 = "HP2-4BAND-3090_4band_arch-500m_1.pth" #@param ["slot","HP2-4BAND-3090_4band_arch-500m_1.pth","HP2-4BAND-3090_4band_arch-500m_2.pth","Vocal_HP_4BAND_3090_arch-124m_AGG.pth","Vocal_HP_4BAND_arch-124m_3090.pth","HP_4BAND_arch-124m_3090.pth","HighPrecison_4band_arch-124m_1.pth","HighPrecison_4band_arch-124m_2.pth","LOFI_2band-1_arch-34m.pth","LOFI_2band-2_arch-34m.pth","NewLayer_4band_arch-130m_1.pth","NewLayer_4band_arch-130m_2.pth","NewLayer_4band_arch-130m_3.pth","MGM-v5-2Band-32000-_arch-default-BETA1.pth","MGM-v5-2Band-32000-_arch-default-BETA2.pth","MGM-v5-3Band-44100-_arch-default-BETA.pth","MGM-v5-4Band-44100-_arch-default-BETA1.pth","MGM-v5-4Band-44100-_arch-default-BETA2.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA1.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA2-AGR.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA1.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA2.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA1.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA2.pth"]
model_2 = "HP2-4BAND-3090_4band_arch-500m_2.pth" #@param ["slot","HP2-4BAND-3090_4band_arch-500m_1.pth","HP2-4BAND-3090_4band_arch-500m_2.pth","Vocal_HP_4BAND_3090_arch-124m_AGG.pth","Vocal_HP_4BAND_arch-124m_3090.pth","HP_4BAND_arch-124m_3090.pth","HighPrecison_4band_arch-124m_1.pth","HighPrecison_4band_arch-124m_2.pth","LOFI_2band-1_arch-34m.pth","LOFI_2band-2_arch-34m.pth","NewLayer_4band_arch-130m_1.pth","NewLayer_4band_arch-130m_2.pth","NewLayer_4band_arch-130m_3.pth","MGM-v5-2Band-32000-_arch-default-BETA1.pth","MGM-v5-2Band-32000-_arch-default-BETA2.pth","MGM-v5-3Band-44100-_arch-default-BETA.pth","MGM-v5-4Band-44100-_arch-default-BETA1.pth","MGM-v5-4Band-44100-_arch-default-BETA2.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA1.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA2-AGR.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA1.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA2.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA1.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA2.pth"]
model_3 = "slot" #@param ["slot","HP2-4BAND-3090_4band_arch-500m_1.pth","HP2-4BAND-3090_4band_arch-500m_2.pth","Vocal_HP_4BAND_3090_arch-124m_AGG.pth","Vocal_HP_4BAND_arch-124m_3090.pth","HP_4BAND_arch-124m_3090.pth","HighPrecison_4band_arch-124m_1.pth","HighPrecison_4band_arch-124m_2.pth","LOFI_2band-1_arch-34m.pth","LOFI_2band-2_arch-34m.pth","NewLayer_4band_arch-130m_1.pth","NewLayer_4band_arch-130m_2.pth","NewLayer_4band_arch-130m_3.pth","MGM-v5-2Band-32000-_arch-default-BETA1.pth","MGM-v5-2Band-32000-_arch-default-BETA2.pth","MGM-v5-3Band-44100-_arch-default-BETA.pth","MGM-v5-4Band-44100-_arch-default-BETA1.pth","MGM-v5-4Band-44100-_arch-default-BETA2.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA1.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA2-AGR.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA1.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA2.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA1.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA2.pth"]
model_4 = "slot" #@param ["slot","HP2-4BAND-3090_4band_arch-500m_1.pth","HP2-4BAND-3090_4band_arch-500m_2.pth","Vocal_HP_4BAND_3090_arch-124m_AGG.pth","Vocal_HP_4BAND_arch-124m_3090.pth","HP_4BAND_arch-124m_3090.pth","HighPrecison_4band_arch-124m_1.pth","HighPrecison_4band_arch-124m_2.pth","LOFI_2band-1_arch-34m.pth","LOFI_2band-2_arch-34m.pth","NewLayer_4band_arch-130m_1.pth","NewLayer_4band_arch-130m_2.pth","NewLayer_4band_arch-130m_3.pth","MGM-v5-2Band-32000-_arch-default-BETA1.pth","MGM-v5-2Band-32000-_arch-default-BETA2.pth","MGM-v5-3Band-44100-_arch-default-BETA.pth","MGM-v5-4Band-44100-_arch-default-BETA1.pth","MGM-v5-4Band-44100-_arch-default-BETA2.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA1.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA2-AGR.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA1.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA2.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA1.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA2.pth"]
model_5 = "slot" #@param ["slot","HP2-4BAND-3090_4band_arch-500m_1.pth","HP2-4BAND-3090_4band_arch-500m_2.pth","Vocal_HP_4BAND_3090_arch-124m_AGG.pth","Vocal_HP_4BAND_arch-124m_3090.pth","HP_4BAND_arch-124m_3090.pth","HighPrecison_4band_arch-124m_1.pth","HighPrecison_4band_arch-124m_2.pth","LOFI_2band-1_arch-34m.pth","LOFI_2band-2_arch-34m.pth","NewLayer_4band_arch-130m_1.pth","NewLayer_4band_arch-130m_2.pth","NewLayer_4band_arch-130m_3.pth","MGM-v5-2Band-32000-_arch-default-BETA1.pth","MGM-v5-2Band-32000-_arch-default-BETA2.pth","MGM-v5-3Band-44100-_arch-default-BETA.pth","MGM-v5-4Band-44100-_arch-default-BETA1.pth","MGM-v5-4Band-44100-_arch-default-BETA2.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA1.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA2-AGR.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA1.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA2.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA1.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA2.pth"]
model_6 = "slot" #@param ["slot","HP2-4BAND-3090_4band_arch-500m_1.pth","HP2-4BAND-3090_4band_arch-500m_2.pth","Vocal_HP_4BAND_3090_arch-124m_AGG.pth","Vocal_HP_4BAND_arch-124m_3090.pth","HP_4BAND_arch-124m_3090.pth","HighPrecison_4band_arch-124m_1.pth","HighPrecison_4band_arch-124m_2.pth","LOFI_2band-1_arch-34m.pth","LOFI_2band-2_arch-34m.pth","NewLayer_4band_arch-130m_1.pth","NewLayer_4band_arch-130m_2.pth","NewLayer_4band_arch-130m_3.pth","MGM-v5-2Band-32000-_arch-default-BETA1.pth","MGM-v5-2Band-32000-_arch-default-BETA2.pth","MGM-v5-3Band-44100-_arch-default-BETA.pth","MGM-v5-4Band-44100-_arch-default-BETA1.pth","MGM-v5-4Band-44100-_arch-default-BETA2.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA1.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA2-AGR.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA1.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA2.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA1.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA2.pth"]
model_7 = "slot" #@param ["slot","HP2-4BAND-3090_4band_arch-500m_1.pth","HP2-4BAND-3090_4band_arch-500m_2.pth","Vocal_HP_4BAND_3090_arch-124m_AGG.pth","Vocal_HP_4BAND_arch-124m_3090.pth","HP_4BAND_arch-124m_3090.pth","HighPrecison_4band_arch-124m_1.pth","HighPrecison_4band_arch-124m_2.pth","LOFI_2band-1_arch-34m.pth","LOFI_2band-2_arch-34m.pth","NewLayer_4band_arch-130m_1.pth","NewLayer_4band_arch-130m_2.pth","NewLayer_4band_arch-130m_3.pth","MGM-v5-2Band-32000-_arch-default-BETA1.pth","MGM-v5-2Band-32000-_arch-default-BETA2.pth","MGM-v5-3Band-44100-_arch-default-BETA.pth","MGM-v5-4Band-44100-_arch-default-BETA1.pth","MGM-v5-4Band-44100-_arch-default-BETA2.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA1.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA2-AGR.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA1.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA2.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA1.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA2.pth"]
model_8 = "slot" #@param ["slot","HP2-4BAND-3090_4band_arch-500m_1.pth","HP2-4BAND-3090_4band_arch-500m_2.pth","Vocal_HP_4BAND_3090_arch-124m_AGG.pth","Vocal_HP_4BAND_arch-124m_3090.pth","HP_4BAND_arch-124m_3090.pth","HighPrecison_4band_arch-124m_1.pth","HighPrecison_4band_arch-124m_2.pth","LOFI_2band-1_arch-34m.pth","LOFI_2band-2_arch-34m.pth","NewLayer_4band_arch-130m_1.pth","NewLayer_4band_arch-130m_2.pth","NewLayer_4band_arch-130m_3.pth","MGM-v5-2Band-32000-_arch-default-BETA1.pth","MGM-v5-2Band-32000-_arch-default-BETA2.pth","MGM-v5-3Band-44100-_arch-default-BETA.pth","MGM-v5-4Band-44100-_arch-default-BETA1.pth","MGM-v5-4Band-44100-_arch-default-BETA2.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA1.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA2-AGR.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA1.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA2.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA1.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA2.pth"]
model_9 = "slot" #@param ["slot","HP2-4BAND-3090_4band_arch-500m_1.pth","HP2-4BAND-3090_4band_arch-500m_2.pth","Vocal_HP_4BAND_3090_arch-124m_AGG.pth","Vocal_HP_4BAND_arch-124m_3090.pth","HP_4BAND_arch-124m_3090.pth","HighPrecison_4band_arch-124m_1.pth","HighPrecison_4band_arch-124m_2.pth","LOFI_2band-1_arch-34m.pth","LOFI_2band-2_arch-34m.pth","NewLayer_4band_arch-130m_1.pth","NewLayer_4band_arch-130m_2.pth","NewLayer_4band_arch-130m_3.pth","MGM-v5-2Band-32000-_arch-default-BETA1.pth","MGM-v5-2Band-32000-_arch-default-BETA2.pth","MGM-v5-3Band-44100-_arch-default-BETA.pth","MGM-v5-4Band-44100-_arch-default-BETA1.pth","MGM-v5-4Band-44100-_arch-default-BETA2.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA1.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA2-AGR.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA1.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA2.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA1.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA2.pth"]
model_10 = "slot" #@param ["slot","HP2-4BAND-3090_4band_arch-500m_1.pth","HP2-4BAND-3090_4band_arch-500m_2.pth","Vocal_HP_4BAND_3090_arch-124m_AGG.pth","Vocal_HP_4BAND_arch-124m_3090.pth","HP_4BAND_arch-124m_3090.pth","HighPrecison_4band_arch-124m_1.pth","HighPrecison_4band_arch-124m_2.pth","LOFI_2band-1_arch-34m.pth","LOFI_2band-2_arch-34m.pth","NewLayer_4band_arch-130m_1.pth","NewLayer_4band_arch-130m_2.pth","NewLayer_4band_arch-130m_3.pth","MGM-v5-2Band-32000-_arch-default-BETA1.pth","MGM-v5-2Band-32000-_arch-default-BETA2.pth","MGM-v5-3Band-44100-_arch-default-BETA.pth","MGM-v5-4Band-44100-_arch-default-BETA1.pth","MGM-v5-4Band-44100-_arch-default-BETA2.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA1.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA2-AGR.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA1.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA2.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA1.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA2.pth"]
model_11 = "slot" #@param ["slot","HP2-4BAND-3090_4band_arch-500m_1.pth","HP2-4BAND-3090_4band_arch-500m_2.pth","Vocal_HP_4BAND_3090_arch-124m_AGG.pth","Vocal_HP_4BAND_arch-124m_3090.pth","HP_4BAND_arch-124m_3090.pth","HighPrecison_4band_arch-124m_1.pth","HighPrecison_4band_arch-124m_2.pth","LOFI_2band-1_arch-34m.pth","LOFI_2band-2_arch-34m.pth","NewLayer_4band_arch-130m_1.pth","NewLayer_4band_arch-130m_2.pth","NewLayer_4band_arch-130m_3.pth","MGM-v5-2Band-32000-_arch-default-BETA1.pth","MGM-v5-2Band-32000-_arch-default-BETA2.pth","MGM-v5-3Band-44100-_arch-default-BETA.pth","MGM-v5-4Band-44100-_arch-default-BETA1.pth","MGM-v5-4Band-44100-_arch-default-BETA2.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA1.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA2-AGR.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA1.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA2.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA1.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA2.pth"]
model_12 = "slot" #@param ["slot","HP2-4BAND-3090_4band_arch-500m_1.pth","HP2-4BAND-3090_4band_arch-500m_2.pth","Vocal_HP_4BAND_3090_arch-124m_AGG.pth","Vocal_HP_4BAND_arch-124m_3090.pth","HP_4BAND_arch-124m_3090.pth","HighPrecison_4band_arch-124m_1.pth","HighPrecison_4band_arch-124m_2.pth","LOFI_2band-1_arch-34m.pth","LOFI_2band-2_arch-34m.pth","NewLayer_4band_arch-130m_1.pth","NewLayer_4band_arch-130m_2.pth","NewLayer_4band_arch-130m_3.pth","MGM-v5-2Band-32000-_arch-default-BETA1.pth","MGM-v5-2Band-32000-_arch-default-BETA2.pth","MGM-v5-3Band-44100-_arch-default-BETA.pth","MGM-v5-4Band-44100-_arch-default-BETA1.pth","MGM-v5-4Band-44100-_arch-default-BETA2.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA1.pth","MGM-v5-KAROKEE-32000-_arch-default-BETA2-AGR.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA1.pth","MGM-v5-MIDSIDE-44100-_arch-default-BETA2.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA1.pth","MGM-v5-Vocal_2Band-32000-_arch-default-BETA2.pth"]

model_1 = modelPath(model_1)
model_2 = modelPath(model_2)
model_3 = modelPath(model_3)
model_4 = modelPath(model_4)
model_5 = modelPath(model_5)
model_6 = modelPath(model_6)
model_7 = modelPath(model_7)
model_8 = modelPath(model_8)
model_9 = modelPath(model_9)
model_10 = modelPath(model_10)
model_11 = modelPath(model_11)
model_12 = modelPath(model_12)
if 'https://' in input:
    titlename,inputsha=YouTube(input)
    get_ipython().system(f"python ensemble_colab.py {FlipVocalModels} --aggressiveness {aggressiveness} -w {window_size} --high_end_process {high_end_process} --suppress --input '{inputsha}' --model_ens {model_1} {model_2} {model_3} {model_4} {model_5} {model_6} {model_7} {model_8} {model_9} {model_10} {model_11} {model_12}")
    os.rename(rf'separated/{os.path.splitext(os.path.basename(inputsha))[0]}_Ensembled_Instruments.wav',rf'separated/{titlename}_Ensembled_Instruments.wav')
    os.rename(rf'separated/{os.path.splitext(os.path.basename(inputsha))[0]}_Ensembled_Vocals.wav',rf'separated/{titlename}_Ensembled_Vocals.wav')
else:
    input = 'tracks/' + input
    get_ipython().system(f"python ensemble_colab.py {FlipVocalModels} --aggressiveness {aggressiveness} -w {window_size} --high_end_process {high_end_process} --suppress --input '{input}' --model_ens {model_1} {model_2} {model_3} {model_4} {model_5} {model_6} {model_7} {model_8} {model_9} {model_10} {model_11} {model_12}")

# %% [markdown]
# ---

# %%
#@markdown ### Similarity Extractor
#@markdown You need two Instrumentals, or a two different language song (Upload your files in Separated folder).
Track_1 = 'Enter track 1' #@param {type:"string"}
Track_2 = 'Enter track 2' #@param {type:"string"}
Track_1 = 'separated/' + Track_1
Track_2 = 'separated/' + Track_2

# #@markdown Sample rate
# samplerate = 44100 #@param ["8000","11025","16000","22050","32000","44100","48000","88200","96000","176400","192000","352800","384000"]

window_size = 352 #@param {type:"integer"}
aggressiveness = '0.75' #@param {type:"string"}
gpu = True #@param {type:"boolean"}
if gpu:
  gpu = '--gpu 0'
else:
  gpu = ''
#@markdown Auto align your tracks if your tracks aren't aligned.
alignTracks = True #@param {type:"boolean"}
if alignTracks:
  alignTracks = '--align'
else:
  alignTracks = ''
#@markdown Export difference of both tracks
extractDifference = True #@param {type:"boolean"}
if extractDifference:
  extractDifference = '--difference'
else:
  extractDifference = ''
#@markdown Process **twice ( ͡° ͜ʖ ͡°)**  for better result
doubleExtraction = True #@param {type:"boolean"}
if doubleExtraction:
  doubleExtraction = '--double'
else:
  doubleExtraction = ''
get_ipython().system(f'python3 similarity_extractor.py --track1 "{Track_1}" --track2 "{Track_2}" --wsize {window_size} --agr {aggressiveness} --sr 44100 {alignTracks} {extractDifference} {doubleExtraction} {gpu} --model "models/v5/27_2_512_2048.pth"')

# %% [markdown]
# report errors to `Hv#3868`
# --

# %% [markdown]
# ###**Best settings in my opinon:**
# <p><sup>Window size: 352</sup></p>
# <p><sup>Model: HP2-4BAND-3090_4band_arch-500m_1.pth</sup></p>
# <p><sup>Parameter: 4band_44100.json</sup></p>
# <p><sup>TTA: ON</sup></p>
# <p><sup>Aggressiveness: 0.275</sup></p>
